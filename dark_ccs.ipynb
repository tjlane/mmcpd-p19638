# %%
import os
from glob import glob
import reciprocalspaceship as rs

# %%
base_dir = "/Users/tjlane/Desktop/PL-workshop/dark_stability/"
column_name = "IMEAN"

df = None

mtz_paths = sorted(glob(base_dir + "dark_intensities/*.mtz"))
for i,mtz_path in enumerate(mtz_paths):
    print(mtz_path)

    if df is None:
        df = rs.read_mtz(mtz_path)[[column_name]]
    else:
        ds_name = os.path.basename(mtz_path)[:-4]
        new_df = rs.read_mtz(mtz_path)[[column_name]]
        df = df.join(new_df, how='inner', check_isomorphous=False, rsuffix=ds_name)
# Out:
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/00_superdark.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/01_truedark.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/02_3ps.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/03_300ps.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/04_1ns.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/05_3ns.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/06_10ns.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/07_30ns.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/08_1us.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/09_10us.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/10_30us.mtz
# /Users/tjlane/Desktop/PL-workshop/dark_stability/dark_intensities/11_100us.mtz

# %%
mapper = {}
for column in df.columns:
    mapper.update({column: column[8:]})
mapper['F'] = 'dark'
print(mapper)

df = df.rename(columns=mapper)

df
# Out:
# {'IMEAN': '', 'IMEAN01_truedark': 'truedark', 'IMEAN02_3ps': '3ps', 'IMEAN03_300ps': '300ps', 'IMEAN04_1ns': '1ns', 'IMEAN05_3ns': '3ns', 'IMEAN06_10ns': '10ns', 'IMEAN07_30ns': '30ns', 'IMEAN08_1us': '1us', 'IMEAN09_10us': '10us', 'IMEAN10_30us': '30us', 'IMEAN11_100us': '100us', 'F': 'dark'}
#                    truedark      3ps   300ps       1ns       3ns     10ns  \
# H  K L
# 0  0 6  229924.72 1131067.0 315975.3 9242.69 100549.81 222083.88 83165.26
#      7    -329.13  -1534.36  -202.11 -829.48   -541.45   -373.91   -385.6
#      8      92.68     94.56   126.17  178.39     181.6      -8.3   -18.65
#      9      -9.26   -101.78   -22.93  -11.42     33.51     50.81   -70.15
#      10   3250.99   6270.48  4897.48 4490.97    2482.2   2621.19   3072.2
# ...           ...       ...      ...     ...       ...       ...      ...
# 30 5 5      59.45   -796.41     95.4 -321.12     57.73     61.07    19.19
#    6 1      15.38    519.05  -237.55 -330.78     72.99    -86.17  -437.33
#    7 1       3.61     193.2   132.98 -147.38     -1.63     54.56   255.61
#    8 2       5.09    352.94  -495.44  383.84    228.04   -135.56   258.95
#    9 3      38.27      66.2  -354.97   -88.6    -39.89     82.57     75.5
#
#              30ns      1us    10us      30us     100us
# H  K L
# 0  0 6  119942.85 72951.21 77082.2 279357.72 121274.68
#      7    -145.89  -396.65 -127.64  -1074.34   -207.49
#      8     -93.67    91.51  242.68    655.77     167.5
#      9     -44.28  -150.82  -69.09     61.11     88.58
#      10   2148.36  2409.92 4101.99   6335.23   4266.88
# ...           ...      ...     ...       ...       ...
# 30 5 5      23.98   141.97  447.23    416.33   -174.72
#    6 1      55.17    -9.01   10.26   -215.86   -407.55
#    7 1      -46.1   104.67 -225.93   -347.31    313.46
#    8 2     -46.52    -58.6  140.93    -359.4     717.8
#    9 3      65.65    -5.29  537.75    926.96   -309.44
#
# [66261 rows x 12 columns]

# %%
corr = df.corr()
html = corr.style.background_gradient(cmap='coolwarm_r', axis=None).set_precision(3)
html
# Out:
# /var/folders/s9/bht_sc9n7ys6m0q3h_3htntc0000gn/T/ipykernel_27384/3577800620.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   html = corr.style.background_gradient(cmap='coolwarm_r', axis=None).set_precision(3)
# <style type="text/css">
# #T_834a9_row0_col0, #T_834a9_row1_col1, #T_834a9_row2_col2, #T_834a9_row3_col3, #T_834a9_row4_col4, #T_834a9_row5_col5, #T_834a9_row6_col6, #T_834a9_row7_col7, #T_834a9_row8_col8, #T_834a9_row9_col9, #T_834a9_row10_col10, #T_834a9_row11_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_834a9_row0_col1, #T_834a9_row1_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_834a9_row0_col2, #T_834a9_row2_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_834a9_row0_col3, #T_834a9_row3_col0, #T_834a9_row5_col9, #T_834a9_row9_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_834a9_row0_col4, #T_834a9_row4_col0, #T_834a9_row4_col9, #T_834a9_row9_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_834a9_row0_col5, #T_834a9_row5_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_834a9_row0_col6, #T_834a9_row6_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_834a9_row0_col7, #T_834a9_row7_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_834a9_row0_col8, #T_834a9_row0_col11, #T_834a9_row8_col0, #T_834a9_row11_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_834a9_row0_col9, #T_834a9_row9_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_834a9_row0_col10, #T_834a9_row4_col8, #T_834a9_row8_col4, #T_834a9_row10_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_834a9_row1_col2, #T_834a9_row2_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_834a9_row1_col3, #T_834a9_row3_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_834a9_row1_col4, #T_834a9_row4_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_834a9_row1_col5, #T_834a9_row5_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_834a9_row1_col6, #T_834a9_row6_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_834a9_row1_col7, #T_834a9_row7_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_834a9_row1_col8, #T_834a9_row8_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_834a9_row1_col9, #T_834a9_row9_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_834a9_row1_col10, #T_834a9_row10_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_834a9_row1_col11, #T_834a9_row11_col1 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_834a9_row2_col3, #T_834a9_row3_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_834a9_row2_col4, #T_834a9_row4_col2, #T_834a9_row4_col6, #T_834a9_row6_col4, #T_834a9_row6_col8, #T_834a9_row7_col11, #T_834a9_row8_col6, #T_834a9_row11_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_834a9_row2_col5, #T_834a9_row5_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_834a9_row2_col6, #T_834a9_row3_col4, #T_834a9_row4_col3, #T_834a9_row6_col2, #T_834a9_row9_col10, #T_834a9_row10_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_834a9_row2_col7, #T_834a9_row7_col2, #T_834a9_row9_col11, #T_834a9_row11_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_834a9_row2_col8, #T_834a9_row8_col2, #T_834a9_row8_col10, #T_834a9_row10_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_834a9_row2_col9, #T_834a9_row3_col9, #T_834a9_row5_col10, #T_834a9_row9_col2, #T_834a9_row9_col3, #T_834a9_row10_col5, #T_834a9_row10_col11, #T_834a9_row11_col10 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_834a9_row2_col10, #T_834a9_row10_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_834a9_row2_col11, #T_834a9_row7_col9, #T_834a9_row9_col7, #T_834a9_row11_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_834a9_row3_col5, #T_834a9_row5_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_834a9_row3_col6, #T_834a9_row6_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_834a9_row3_col7, #T_834a9_row7_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_834a9_row3_col8, #T_834a9_row8_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_834a9_row3_col10, #T_834a9_row10_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_834a9_row3_col11, #T_834a9_row11_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_834a9_row4_col5, #T_834a9_row5_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_834a9_row4_col7, #T_834a9_row7_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_834a9_row4_col10, #T_834a9_row5_col7, #T_834a9_row7_col5, #T_834a9_row10_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_834a9_row4_col11, #T_834a9_row11_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_834a9_row5_col6, #T_834a9_row6_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_834a9_row5_col8, #T_834a9_row8_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_834a9_row5_col11, #T_834a9_row11_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_834a9_row6_col7, #T_834a9_row6_col9, #T_834a9_row7_col6, #T_834a9_row8_col9, #T_834a9_row9_col6, #T_834a9_row9_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_834a9_row6_col10, #T_834a9_row10_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_834a9_row6_col11, #T_834a9_row7_col8, #T_834a9_row7_col10, #T_834a9_row8_col7, #T_834a9_row10_col7, #T_834a9_row11_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_834a9_row8_col11, #T_834a9_row11_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_834a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_834a9_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_834a9_level0_col1" class="col_heading level0 col1" >truedark</th>
#       <th id="T_834a9_level0_col2" class="col_heading level0 col2" >3ps</th>
#       <th id="T_834a9_level0_col3" class="col_heading level0 col3" >300ps</th>
#       <th id="T_834a9_level0_col4" class="col_heading level0 col4" >1ns</th>
#       <th id="T_834a9_level0_col5" class="col_heading level0 col5" >3ns</th>
#       <th id="T_834a9_level0_col6" class="col_heading level0 col6" >10ns</th>
#       <th id="T_834a9_level0_col7" class="col_heading level0 col7" >30ns</th>
#       <th id="T_834a9_level0_col8" class="col_heading level0 col8" >1us</th>
#       <th id="T_834a9_level0_col9" class="col_heading level0 col9" >10us</th>
#       <th id="T_834a9_level0_col10" class="col_heading level0 col10" >30us</th>
#       <th id="T_834a9_level0_col11" class="col_heading level0 col11" >100us</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_834a9_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_834a9_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_834a9_row0_col1" class="data row0 col1" >0.968</td>
#       <td id="T_834a9_row0_col2" class="data row0 col2" >0.996</td>
#       <td id="T_834a9_row0_col3" class="data row0 col3" >0.977</td>
#       <td id="T_834a9_row0_col4" class="data row0 col4" >0.994</td>
#       <td id="T_834a9_row0_col5" class="data row0 col5" >0.996</td>
#       <td id="T_834a9_row0_col6" class="data row0 col6" >0.990</td>
#       <td id="T_834a9_row0_col7" class="data row0 col7" >0.998</td>
#       <td id="T_834a9_row0_col8" class="data row0 col8" >0.991</td>
#       <td id="T_834a9_row0_col9" class="data row0 col9" >0.988</td>
#       <td id="T_834a9_row0_col10" class="data row0 col10" >0.994</td>
#       <td id="T_834a9_row0_col11" class="data row0 col11" >0.991</td>
#     </tr>
#     <tr>
#       <th id="T_834a9_level0_row1" class="row_heading level0 row1" >truedark</th>
#       <td id="T_834a9_row1_col0" class="data row1 col0" >0.968</td>
#       <td id="T_834a9_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_834a9_row1_col2" class="data row1 col2" >0.964</td>
#       <td id="T_834a9_row1_col3" class="data row1 col3" >0.910</td>
#       <td id="T_834a9_row1_col4" class="data row1 col4" >0.944</td>
#       <td id="T_834a9_row1_col5" class="data row1 col5" >0.981</td>
#       <td id="T_834a9_row1_col6" class="data row1 col6" >0.934</td>
#       <td id="T_834a9_row1_col7" class="data row1 col7" >0.957</td>
#       <td id="T_834a9_row1_col8" class="data row1 col8" >0.932</td>
#       <td id="T_834a

# %%
with open(base_dir + 'corrmatrix.html', 'w') as f:
    f.write(html.render())
# Out:
# /var/folders/s9/bht_sc9n7ys6m0q3h_3htntc0000gn/T/ipykernel_27384/2184002587.py:2: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   f.write(html.render())
